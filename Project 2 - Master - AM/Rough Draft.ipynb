# %% [markdown]
# # Project 2: Ames Housing Data and Kaggle Challenge

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# ---

# %% [markdown]
# ## Executive Summary

# %% [markdown]
# ## Table of Contents:
# - [Ames Housing Data Import and Cleaning](#Ames-Housing-Data-Import-and-Cleaning)
# - [Data Dictionary](#Data-Dictionary)
# - [Data Cleaning](#Data-Cleaning)
# - [Exploratory Data Analysis](#Exploratory-Data-Analysis)
# - [Data Visualization](#Visualize-the-data)
# - [Modeling](#Modeling)
# - [Baseline Model](#Baseline-Model)
# - [Linear Regression](#Linear-Regression)
# - [Model Selection](#Model-Selection)
# - [Model Evaluation](#Model-Evaluation)
# - [Conclusion](#Conclusion)
# - [Recommendations](#Recommendations)
# - [References](#References)

# %% [markdown]
# ## Ames Housing Data Import and Cleaning

# %%
# imports
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression

# %%
# load in training and test data

df = pd.read_csv("datasets/train.csv")
test_df = pd.read_csv("datasets/test.csv")

# %% [markdown]
# ## Data Dictionary

# %% [markdown]
# [Ames Housing Data](http://jse.amstat.org/v19n3/decock/DataDocumentation.txt)

# %% [markdown]
# ## Data Cleaning

# %%
# view all columns

pd.set_option('display.max_columns', None)
df.head(10)
# Out:
#      Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0   109  533352170           60        RL           NaN     13517   Pave
# 1   544  531379050           60        RL          43.0     11492   Pave
# 2   153  535304180           20        RL          68.0      7922   Pave
# 3   318  916386060           60        RL          73.0      9802   Pave
# 4   255  906425045           50        RL          82.0     14235   Pave
# 5   138  535126040           20        RL         137.0     16492   Pave
# 6  2827  908186070          180        RM          35.0      3675   Pave
# 7   145  535154050           20        RL           NaN     12160   Pave
# 8  1942  535353130           20        RL           NaN     15783   Pave
# 9  1956  535426130           60        RL          70.0     11606   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0   NaN       IR1          Lvl    AllPub    CulDSac        Gtl       Sawyer
# 1   NaN       IR1          Lvl    AllPub    CulDSac        Gtl      SawyerW
# 2   NaN       Reg          Lvl    AllPub     Inside        Gtl        NAmes
# 3   NaN       Reg          Lvl    AllPub     Inside        Gtl       Timber
# 4   NaN       IR1          Lvl    AllPub     Inside        Gtl      SawyerW
# 5   NaN       IR1          Lvl    AllPub     Corner        Gtl        NAmes
# 6   NaN       Reg          Lvl    AllPub     Inside        Gtl      Edwards
# 7   NaN       IR1          Lvl    AllPub     Inside        Gtl        NAmes
# 8   NaN       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 9   NaN       IR1          HLS    AllPub     Inside        Sev        NAmes
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond  \
# 0        RRAe        Norm      1Fam      2Story             6             8
# 1        Norm        Norm      1Fam      2Story             7             5
# 2        Norm        Norm      1Fam      1Story             5             7
# 3        Norm        Norm      1Fam      2Story             5             5
# 4        Norm        Norm      1Fam      1.5Fin             6             8
# 5        PosA        Norm      1Fam      1Story             6             6
# 6        Norm        Norm    TwnhsE      SFoyer             6             5
# 7        Norm        Norm      1Fam      1Story             5             5
# 8      Artery        Norm      1Fam      1Story             5             5
# 9        Norm        Norm      1Fam      2Story             5             5
#
#    Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd  \
# 0        1976            2005      Gable   CompShg      HdBoard      Plywood
# 1        1996            1997      Gable   CompShg      VinylSd      VinylSd
# 2        1953            2007      Gable   CompShg      VinylSd      VinylSd
# 3        2006            2007      Gable   CompShg      VinylSd      VinylSd
# 4        1900            1993      Gable   CompShg      Wd Sdng      Plywood
# 5        1966            2002      Gable   CompShg      BrkFace      Plywood
# 6        2005            2006      Gable   CompShg      VinylSd      VinylSd
# 7        1959            1959        Hip   CompShg      Plywood      Plywood
# 8        1952            1952      Gable   CompShg      Wd Sdng      Wd Sdng
# 9        1969            1969      Gable   CompShg      Plywood      Plywood
#
#   Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation Bsmt Qual  \
# 0      BrkFace         289.0         Gd         TA     CBlock        TA
# 1      BrkFace         132.0         Gd         TA      PConc        Gd
# 2         None           0.0         TA         Gd     CBlock        TA
# 3         None           0.0         TA         TA      PConc        Gd
# 4         None           0.0         TA         TA      PConc        Fa
# 5         None           0.0         Gd         TA     CBlock        TA
# 6      BrkFace          82.0         TA         TA      PConc        Gd
# 7      BrkFace         180.0         TA         TA     CBlock        TA
# 8         None           0.0         TA         TA     CBlock        TA
# 9      BrkFace         192.0         TA         TA      PConc        Gd
#
#   Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  \
# 0        TA            No            GLQ         533.0            Unf
# 1        TA            No            GLQ         637.0            Unf
# 2        TA            No            GLQ         731.0            Unf
# 3        TA            No            Unf           0.0            Unf
# 4        Gd            No            Unf           0.0            Unf
# 5        TA            No            ALQ         247.0            Rec
# 6        TA            Gd            GLQ         547.0            Unf
# 7        TA            No            Rec        1000.0            Unf
# 8        TA            No            Rec         292.0            Unf
# 9        TA            Av            Rec         650.0            Unf
#
#    BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF Heating Heating QC Central Air  \
# 0           0.0        192.0          725.0    GasA         Ex           Y
# 1           0.0        276.0          913.0    GasA         Ex           Y
# 2           0.0        326.0         1057.0    GasA         TA           Y
# 3           0.0        384.0          384.0    GasA         Gd           Y
# 4           0.0        676.0          676.0    GasA         TA           Y
# 5         713.0        557.0         1517.0    GasA         Ex           Y
# 6           0.0          0.0          547.0    GasA         Gd           Y
# 7           0.0        188.0         1188.0    GasA         Fa           Y
# 8           0.0        632.0          924.0    GasA         TA           Y
# 9           0.0        390.0         1040.0    GasA         TA           Y
#
#   Electrical  1st Flr SF  2nd Flr SF  Low Qual Fin SF  Gr Liv Area  \
# 0      SBrkr         725         754                0         1479
# 1      SBrkr         913        1209                0         2122
# 2      SBrkr        1057           0                0         1057
# 3      SBrkr         744         700                0         1444
# 4      SBrkr         831         614                0         1445
# 5      SBrkr        1888           0                0         1888
# 6      SBrkr        1072           0                0         1072
# 7      SBrkr        1188           0                0         1188
# 8      SBrkr         924           0                0          924
# 9      SBrkr        1040        1040                0         2080
#
#    Bsmt Full Bath  Bsmt Half Bath  Full Bath  Half Bath  Bedroom AbvGr  \
# 0             0.0             0.0          2          1              3
# 1             1.0             0.0          2          1              4
# 2             1.0             0.0          1          0              3
# 3             0.0             0.0          2          1              3
# 4             0.0             0.0          2          0              3
# 5             0.0             0.0          2          1              2
# 6             1.0             0.0          2          0              2
# 7             1.0             0.0          1          0              3
# 8             0.0             0.0          1          0              2
# 9             0.0             1.0          1          2              5
#
#    Kitchen AbvGr Kitchen Qual  TotRms AbvGrd Functional  Fireplaces  \
# 0              1           Gd              6        Typ           0
# 1              1           Gd              8        Typ           1
# 2              1           Gd              5        Typ           0
# 3              1           TA              7        Typ           0
# 4              1           TA              6        Typ           0
# 5              1           Gd              6        Mod           1
# 6              1           TA              5        Typ           0
# 7              1           TA              6        Typ           0
# 8              1           TA              6        Typ           0
# 9              1           Fa              9        Typ           2
#
#   Fireplace Qu Garage Type  Garage Yr Blt Garage Finish  Garage Cars  \
# 0          NaN      Attchd         1976.0           RFn          2.0
# 1           TA      Attchd         1997.0           RFn          2.0
# 2          NaN      Detchd         1953.0           Unf          1.0
# 3          NaN     BuiltIn         2007.0           Fin          2.0
# 4          NaN      Detchd         1957.0           Unf          2.0
# 5           Gd      Attchd         1966.0           Fin          2.0
# 6          NaN     Basment         2005.0           Fin          2.0
# 7          NaN      Attchd         1959.0           RFn          2.0
# 8          NaN      Detchd         1952.0           Unf          1.0
# 9           TA      Attchd         1969.0           Unf          2.0
#
#    Garage Area Garage Qual Garage Cond Paved Drive  Wood Deck SF  \
# 0        475.0          TA          TA           Y             0
# 1        559.0          TA          TA           Y             0
# 2        246.0          TA          TA           Y             0
# 3        400.0          TA          TA           Y           100
# 4        484.0          TA          TA           N             0
# 5        578.0          TA          TA           Y             0
# 6        525.0          TA          TA           Y             0
# 7        531.0          TA          TA           Y             0
# 8        420.0          TA          TA           Y             0
# 9        504.0          TA          TA           Y           335
#
#    Open Porch SF  Enclosed Porch  3Ssn Porch  Screen Porch  Pool Area Pool QC  \
# 0             44               0           0             0          0     NaN
# 1             74               0           0             0          0     NaN
# 2             52               0           0             0          0     NaN
# 3              0               0           0             0          0     NaN
# 4             59               0           0             0          0     NaN
# 5              0               0           0             0          0     NaN
# 6             44               0           0             0          0     NaN
# 7              0               0           0             0          0     NaN
# 8            324               0           0             0          0     NaN
# 9              0               0           0             0          0     NaN
#
#    Fence Misc Feature  Misc Val  Mo Sold  Yr Sold Sale Type  SalePrice
# 0    NaN          NaN         0        3     2010       WD      130500
# 1    NaN          NaN         0        4     2009       WD      220000
# 2    NaN          NaN         0        1     2010       WD      109000
# 3    NaN          NaN         0        4     2010       WD      174000
# 4    NaN          NaN         0        3     2010       WD      138500
# 5    NaN          NaN         0        6     2010       WD      190000
# 6    NaN          NaN         0        6     2006       New     140000
# 7  MnPrv          NaN         0        5     2010       COD     142000
# 8  MnPrv         Shed       400        6     2007       WD      112500
# 9    NaN          NaN         0        9     2007       WD      135000

# %%
df.columns
# Out:
# Index(['Id', 'PID', 'MS SubClass', 'MS Zoning', 'Lot Frontage', 'Lot Area',
#        'Street', 'Alley', 'Lot Shape', 'Land Contour', 'Utilities',
#        'Lot Config', 'Land Slope', 'Neighborhood', 'Condition 1',
#        'Condition 2', 'Bldg Type', 'House Style', 'Overall Qual',
#        'Overall Cond', 'Year Built', 'Year Remod/Add', 'Roof Style',
#        'Roof Matl', 'Exterior 1st', 'Exterior 2nd', 'Mas Vnr Type',
#        'Mas Vnr Area', 'Exter Qual', 'Exter Cond', 'Foundation', 'Bsmt Qual',
#        'Bsmt Cond', 'Bsmt Exposure', 'BsmtFin Type 1', 'BsmtFin SF 1',
#        'BsmtFin Type 2', 'BsmtFin SF 2', 'Bsmt Unf SF', 'Total Bsmt SF',
#        'Heating', 'Heating QC', 'Central Air', 'Electrical', '1st Flr SF',
#        '2nd Flr SF', 'Low Qual Fin SF', 'Gr Liv Area', 'Bsmt Full Bath',
#        'Bsmt Half Bath', 'Full Bath', 'Half Bath', 'Bedroom AbvGr',
#        'Kitchen AbvGr', 'Kitchen Qual', 'TotRms AbvGrd', 'Functional',
#        'Fireplaces', 'Fireplace Qu', 'Garage Type', 'Garage Yr Blt',
#        'Garage Finish', 'Garage Cars', 'Garage Area', 'Garage Qual',
#        'Garage Cond', 'Paved Drive', 'Wood Deck SF', 'Open Porch SF',
#        'Enclosed Porch', '3Ssn Porch', 'Screen Porch', 'Pool Area', 'Pool QC',
#        'Fence', 'Misc Feature', 'Misc Val', 'Mo Sold', 'Yr Sold', 'Sale Type',
#        'SalePrice'],
#       dtype='object')

# %%
# check number of columns and rows

df.shape
# Out:
# (2051, 81)

# %%
# check datatypes and reference data description

df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2051 entries, 0 to 2050
# Data columns (total 81 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Id               2051 non-null   int64
#  1   PID              2051 non-null   int64
#  2   MS SubClass      2051 non-null   int64
#  3   MS Zoning        2051 non-null   object
#  4   Lot Frontage     1721 non-null   float64
#  5   Lot Area         2051 non-null   int64
#  6   Street           2051 non-null   object
#  7   Alley            140 non-null    object
#  8   Lot Shape        2051 non-null   object
#  9   Land Contour     2051 non-null   object
#  10  Utilities        2051 non-null   object
#  11  Lot Config       2051 non-null   object
#  12  Land Slope       2051 non-null   object
#  13  Neighborhood     2051 non-null   object
#  14  Condition 1      2051 non-null   object
#  15  Condition 2      2051 non-null   object
#  16  Bldg Type        2051 non-null   object
#  17  House Style      2051 non-null   object
#  18  Overall Qual     2051 non-null   int64
#  19  Overall Cond     2051 non-null   int64
#  20  Year Built       2051 non-null   int64
#  21  Year Remod/Add   2051 non-null   int64
#  22  Roof Style       2051 non-null   object
#  23  Roof Matl        2051 non-null   object
#  24  Exterior 1st     2051 non-null   object
#  25  Exterior 2nd     2051 non-null   object
#  26  Mas Vnr Type     2029 non-null   object
#  27  Mas Vnr Area     2029 non-null   float64
#  28  Exter Qual       2051 non-null   object
#  29  Exter Cond       2051 non-null   object
#  30  Foundation       2051 non-null   object
#  31  Bsmt Qual        1996 non-null   object
#  32  Bsmt Cond        1996 non-null   object
#  33  Bsmt Exposure    1993 non-null   object
#  34  BsmtFin Type 1   1996 non-null   object
#  35  BsmtFin SF 1     2050 non-null   float64
#  36  BsmtFin Type 2   1995 non-null   object
#  37  BsmtFin SF 2     2050 non-null   float64
#  38  Bsmt Unf SF      2050 non-null   float64
#  39  Total Bsmt SF    2050 non-null   float64
#  40  Heating          2051 non-null   object
#  41  Heating QC       2051 non-null   object
#  42  Central Air      2051 non-null   object
#  43  Electrical       2051 non-null   object
#  44  1st Flr SF       2051 non-null   int64
#  45  2nd Flr SF       2051 non-null   int64
#  46  Low Qual Fin SF  2051 non-null   int64
#  47  Gr Liv Area      2051 non-null   int64
#  48  Bsmt Full Bath   2049 non-null   float64
#  49  Bsmt Half Bath   2049 non-null   float64
#  50  Full Bath        2051 non-null   int64
#  51  Half Bath        2051 non-null   int64
#  52  Bedroom AbvGr    2051 non-null   int64
#  53  Kitchen AbvGr    2051 non-null   int64
#  54  Kitchen Qual     2051 non-null   object
#  55  TotRms AbvGrd    2051 non-null   int64
#  56  Functional       2051 non-null   object
#  57  Fireplaces       2051 non-null   int64
#  58  Fireplace Qu     1051 non-null   object
#  59  Garage Type      1938 non-null   object
#  60  Garage Yr Blt    1937 non-null   float64
#  61  Garage Finish    1937 non-null   object
#  62  Garage Cars      2050 non-null   float64
#  63  Garage Area      2050 non-null   float64
#  64  Garage Qual      1937 non-null   object
#  65  Garage Cond      1937 non-null   object
#  66  Paved Drive      2051 non-null   object
#  67  Wood Deck SF     2051 non-null   int64
#  68  Open Porch SF    2051 non-null   int64
#  69  Enclosed Porch   2051 non-null   int64
#  70  3Ssn Porch       2051 non-null   int64
#  71  Screen Porch     2051 non-null   int64
#  72  Pool Area        2051 non-null   int64
#  73  Pool QC          9 non-null      object
#  74  Fence            400 non-null    object
#  75  Misc Feature     65 non-null     object
#  76  Misc Val         2051 non-null   int64
#  77  Mo Sold          2051 non-null   int64
#  78  Yr Sold          2051 non-null   int64
#  79  Sale Type        2051 non-null   object
#  80  SalePrice        2051 non-null   int64
# dtypes: float64(11), int64(28), object(42)
# memory usage: 1.3+ MB

# %%
df.describe()
# Out:
#                 Id           PID  MS SubClass  Lot Frontage       Lot Area  \
# count  2051.000000  2.051000e+03  2051.000000   1721.000000    2051.000000
# mean   1474.033642  7.135900e+08    57.008776     69.055200   10065.208191
# std     843.980841  1.886918e+08    42.824223     23.260653    6742.488909
# min       1.000000  5.263011e+08    20.000000     21.000000    1300.000000
# 25%     753.500000  5.284581e+08    20.000000     58.000000    7500.000000
# 50%    1486.000000  5.354532e+08    50.000000     68.000000    9430.000000
# 75%    2198.000000  9.071801e+08    70.000000     80.000000   11513.500000
# max    2930.000000  9.241520e+08   190.000000    313.000000  159000.000000
#
#        Overall Qual  Overall Cond   Year Built  Year Remod/Add  Mas Vnr Area  \
# count   2051.000000   2051.000000  2051.000000     2051.000000   2029.000000
# mean       6.112140      5.562165  1971.708922     1984.190151     99.695909
# std        1.426271      1.104497    30.177889       21.036250    174.963129
# min        1.000000      1.000000  1872.000000     1950.000000      0.000000
# 25%        5.000000      5.000000  1953.500000     1964.500000      0.000000
# 50%        6.000000      5.000000  1974.000000     1993.000000      0.000000
# 75%        7.000000      6.000000  2001.000000     2004.000000    161.000000
# max       10.000000      9.000000  2010.000000     2010.000000   1600.000000
#
#        BsmtFin SF 1  BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF   1st Flr SF  \
# count   2050.000000   2050.000000  2050.000000    2050.000000  2051.000000
# mean     442.300488     47.959024   567.728293    1057.987805  1164.488055
# std      461.204124    165.000901   444.954786     449.410704   396.446923
# min        0.000000      0.000000     0.000000       0.000000   334.000000
# 25%        0.000000      0.000000   220.000000     793.000000   879.500000
# 50%      368.000000      0.000000   474.500000     994.500000  1093.000000
# 75%      733.750000      0.000000   811.000000    1318.750000  1405.000000
# max     5644.000000   1474.000000  2336.000000    6110.000000  5095.000000
#
#         2nd Flr SF  Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  \
# count  2051.000000      2051.000000  2051.000000     2049.000000
# mean    329.329108         5.512921  1499.330083        0.427526
# std     425.671046        51.068870   500.447829        0.522673
# min       0.000000         0.000000   334.000000        0.000000
# 25%       0.000000         0.000000  1129.000000        0.000000
# 50%       0.000000         0.000000  1444.000000        0.000000
# 75%     692.500000         0.000000  1728.500000        1.000000
# max    1862.000000      1064.000000  5642.000000        3.000000
#
#        Bsmt Half Bath    Full Bath    Half Bath  Bedroom AbvGr  Kitchen AbvGr  \
# count     2049.000000  2051.000000  2051.000000    2051.000000    2051.000000
# mean         0.063446     1.577279     0.371039       2.843491       1.042906
# std          0.251705     0.549279     0.501043       0.826618       0.209790
# min          0.000000     0.000000     0.000000       0.000000       0.000000
# 25%          0.000000     1.000000     0.000000       2.000000       1.000000
# 50%          0.000000     2.000000     0.000000       3.000000       1.000000
# 75%          0.000000     2.000000     1.000000       3.000000       1.000000
# max          2.000000     4.000000     2.000000       8.000000       3.000000
#
#        TotRms AbvGrd   Fireplaces  Garage Yr Blt  Garage Cars  Garage Area  \
# count    2051.000000  2051.000000    1937.000000  2050.000000  2050.000000
# mean        6.435885     0.590931    1978.707796     1.776585   473.671707
# std         1.560225     0.638516      25.441094     0.764537   215.934561
# min         2.000000     0.000000    1895.000000     0.000000     0.000000
# 25%         5.000000     0.000000    1961.000000     1.000000   319.000000
# 50%         6.000000     1.000000    1980.000000     2.000000   480.000000
# 75%         7.000000     1.000000    2002.000000     2.000000   576.000000
# max        15.000000     4.000000    2207.000000     5.000000  1418.000000
#
#        Wood Deck SF  Open Porch SF  Enclosed Porch   3Ssn Porch  Screen Porch  \
# count   2051.000000    2051.000000     2051.000000  2051.000000   2051.000000
# mean      93.833740      47.556802       22.571916     2.591419     16.511458
# std      128.549416      66.747241       59.845110    25.229615     57.374204
# min        0.000000       0.000000        0.000000     0.000000      0.000000
# 25%        0.000000       0.000000        0.000000     0.000000      0.000000
# 50%        0.000000      27.000000        0.000000     0.000000      0.000000
# 75%      168.000000      70.000000        0.000000     0.000000      0.000000
# max     1424.000000     547.000000      432.000000   508.000000    490.000000
#
#          Pool Area      Misc Val      Mo Sold      Yr Sold      SalePrice
# count  2051.000000   2051.000000  2051.000000  2051.000000    2051.000000
# mean      2.397855     51.574354     6.219893  2007.775719  181469.701609
# std      37.782570    573.393985     2.744736     1.312014   79258.659352
# min       0.000000      0.000000     1.000000  2006.000000   12789.000000
# 25%       0.000000      0.000000     4.000000  2007.000000  129825.000000
# 50%       0.000000      0.000000     6.000000  2008.000000  162500.000000
# 75%       0.000000      0.000000     8.000000  2009.000000  214000.000000
# max     800.000000  17000.000000    12.000000  2010.000000  611657.000000

# %%
null_columns = df.columns[df.isnull().any()]
df[null_columns].isnull().sum()
# Out:
# Lot Frontage       330
# Alley             1911
# Mas Vnr Type        22
# Mas Vnr Area        22
# Bsmt Qual           55
# Bsmt Cond           55
# Bsmt Exposure       58
# BsmtFin Type 1      55
# BsmtFin SF 1         1
# BsmtFin Type 2      56
# BsmtFin SF 2         1
# Bsmt Unf SF          1
# Total Bsmt SF        1
# Bsmt Full Bath       2
# Bsmt Half Bath       2
# Fireplace Qu      1000
# Garage Type        113
# Garage Yr Blt      114
# Garage Finish      114
# Garage Cars          1
# Garage Area          1
# Garage Qual        114
# Garage Cond        114
# Pool QC           2042
# Fence             1651
# Misc Feature      1986
# dtype: int64

# %%
# rename columns to snakecase letter

df.columns = df.columns.str.lower().str.replace(" ", "_")

# %%
# get the mean lot frontage for data set

df['lot_frontage'].mean()
# Out:
# 69.05520046484602

# %%
# replace the na values with 69

df['lot_frontage'] = df['lot_frontage'].fillna(69)

# %%
# get the mean masonry veneer area in square feet

df['mas_vnr_area'].mean()
# Out:
# 99.69590931493346

# %%
# replace the na values with 99.7

df['mas_vnr_area'] = df['mas_vnr_area'].fillna(99.7)

# %%
# get the mean type 2 finished square feet

df['bsmtfin_sf_2'].mean()
# Out:
# 47.959024390243904

# %%
# replace the na values with 47.96

df['bsmtfin_sf_2'] = df['bsmtfin_sf_2'].fillna(47.96)

# %%
# get the mean unfinished sqaure feet of basement area

df['bsmt_unf_sf'].mean()
# Out:
# 567.7282926829268

# %%
# replace the na values with 567.72

df['bsmt_unf_sf'] = df['bsmt_unf_sf'].fillna(567.72)

# %%
# get the mean total sqaure feet of basement area

df['total_bsmt_sf'].mean()
# Out:
# 1057.9878048780488

# %%
# replace the na values with 1057.98

df['bsmt_unf_sf'] = df['bsmt_unf_sf'].fillna(1057.98)

# %%
# value count of basement qual
# NA was referenced in the data dictionary as no basement
# This may cause confusion with null values

df['bsmt_qual'].value_counts()
# Out:
# TA    887
# Gd    864
# Ex    184
# Fa     60
# Po      1
# Name: bsmt_qual, dtype: int64

# %%
2051 - 887 - 864 - 184 - 60 - 1
# Out:
# 55

# %%
# value count of basement condition
# NA was referenced in the data dictionary as no basement
# This may cause confusion with null values

df['bsmt_cond'].value_counts()
# Out:
# TA    1834
# Gd      89
# Fa      65
# Po       5
# Ex       3
# Name: bsmt_cond, dtype: int64

# %%
# get the remaining properties with no basement or 0 value

2051 - 1834 - 89 - 65 - 5 - 3
# Out:
# 55

# %% [markdown]
# The number of no basement seems to be consistent with 55 when comparing the basement condition and basement quality. I will fill the values with NoB representing No basment which will make it more clear.

# %%
# fill na values with NoB

df['bsmt_cond'] = df['bsmt_cond'].fillna('NoB')

# %%
# fill na values with NoB

df['bsmt_qual'] = df['bsmt_qual'].fillna('NoB')

# %%
# check unique values of condition, quality should match

df['bsmt_cond'].unique()
# Out:
# array(['TA', 'Gd', 'NoB', 'Fa', 'Po', 'Ex'], dtype=object)

# %%
df['bsmt_full_bath'].value_counts()
# Out:
# 0.0    1200
# 1.0     824
# 2.0      23
# 3.0       2
# Name: bsmt_full_bath, dtype: int64

# %% [markdown]
# The data dictionary explains that a lot of the columns are either nominal or ordinal. I will need to convert these to integers.

# %%
# select the two rows with missing values in bsmt full bath
# these houses are one story and do not have basments

df[df['bsmt_full_bath'].isnull()]
# Out:
#         id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 616   1498  908154080           20        RL         123.0     47007   Pave
# 1327  1342  903230120           20        RM          99.0      5940   Pave
#
#      alley lot_shape land_contour utilities lot_config land_slope  \
# 616    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1327   NaN       IR1          Lvl    AllPub        FR3        Gtl
#
#      neighborhood condition_1 condition_2 bldg_type house_style  overall_qual  \
# 616       Edwards        Norm        Norm      1Fam      1Story             5
# 1327      BrkSide       Feedr        Norm      1Fam      1Story             4
#
#       overall_cond  year_built  year_remod/add roof_style roof_matl  \
# 616              7        1959            1996      Gable   CompShg
# 1327             7        1946            1950      Gable   CompShg
#
#      exterior_1st exterior_2nd mas_vnr_type  mas_vnr_area exter_qual  \
# 616       Plywood      Plywood         None           0.0         TA
# 1327      MetalSd       CBlock         None           0.0         TA
#
#      exter_cond foundation bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  \
# 616          TA       Slab       NoB       NoB           NaN            NaN
# 1327         TA      PConc       NoB       NoB           NaN            NaN
#
#       bsmtfin_sf_1 bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf  \
# 616            0.0            NaN          0.00         0.00            0.0
# 1327           NaN            NaN         47.96       567.72            NaN
#
#      heating heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# 616     GasA         TA           Y      SBrkr        3820           0
# 1327    GasA         TA           Y      FuseA         896           0
#
#       low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 616                 0         3820             NaN             NaN          3
# 1327                0          896             NaN             NaN          1
#
#       half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 616           1              5              1           Ex             11
# 1327          0              2              1           TA              4
#
#      functional  fireplaces fireplace_qu garage_type  garage_yr_blt  \
# 616         Typ           2           Gd      Attchd         1959.0
# 1327        Typ           0          NaN      Detchd         1946.0
#
#      garage_finish  garage_cars  garage_area garage_qual garage_cond  \
# 616            Unf          2.0        624.0          TA          TA
# 1327           Unf          1.0        280.0          TA          TA
#
#      paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  \
# 616            Y             0            372               0           0
# 1327           Y             0              0               0           0
#
#       screen_porch  pool_area pool_qc  fence misc_feature  misc_val  mo_sold  \
# 616              0          0     NaN    NaN          NaN         0        7
# 1327             0          0     NaN  MnPrv          NaN         0        4
#
#       yr_sold sale_type  saleprice
# 616      2008       WD      284700
# 1327     2008     ConLD      79000

# %%
# replace null values with 0

df['bsmt_full_bath'] = df['bsmt_full_bath'].fillna(0)

# %%
# select the two rows with missing values in bsmt half bath
# these houses are one story and do not have basments

df[df['bsmt_half_bath'].isnull()]
# Out:
#         id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 616   1498  908154080           20        RL         123.0     47007   Pave
# 1327  1342  903230120           20        RM          99.0      5940   Pave
#
#      alley lot_shape land_contour utilities lot_config land_slope  \
# 616    NaN       IR1          Lvl    AllPub     Inside        Gtl
# 1327   NaN       IR1          Lvl    AllPub        FR3        Gtl
#
#      neighborhood condition_1 condition_2 bldg_type house_style  overall_qual  \
# 616       Edwards        Norm        Norm      1Fam      1Story             5
# 1327      BrkSide       Feedr        Norm      1Fam      1Story             4
#
#       overall_cond  year_built  year_remod/add roof_style roof_matl  \
# 616              7        1959            1996      Gable   CompShg
# 1327             7        1946            1950      Gable   CompShg
#
#      exterior_1st exterior_2nd mas_vnr_type  mas_vnr_area exter_qual  \
# 616       Plywood      Plywood         None           0.0         TA
# 1327      MetalSd       CBlock         None           0.0         TA
#
#      exter_cond foundation bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  \
# 616          TA       Slab       NoB       NoB           NaN            NaN
# 1327         TA      PConc       NoB       NoB           NaN            NaN
#
#       bsmtfin_sf_1 bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf  \
# 616            0.0            NaN          0.00         0.00            0.0
# 1327           NaN            NaN         47.96       567.72            NaN
#
#      heating heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# 616     GasA         TA           Y      SBrkr        3820           0
# 1327    GasA         TA           Y      FuseA         896           0
#
#       low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 616                 0         3820             0.0             NaN          3
# 1327                0          896             0.0             NaN          1
#
#       half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 616           1              5              1           Ex             11
# 1327          0              2              1           TA              4
#
#      functional  fireplaces fireplace_qu garage_type  garage_yr_blt  \
# 616         Typ           2           Gd      Attchd         1959.0
# 1327        Typ           0          NaN      Detchd         1946.0
#
#      garage_finish  garage_cars  garage_area garage_qual garage_cond  \
# 616            Unf          2.0        624.0          TA          TA
# 1327           Unf          1.0        280.0          TA          TA
#
#      paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  \
# 616            Y             0            372               0           0
# 1327           Y             0              0               0           0
#
#       screen_porch  pool_area pool_qc  fence misc_feature  misc_val  mo_sold  \
# 616              0          0     NaN    NaN          NaN         0        7
# 1327             0          0     NaN  MnPrv          NaN         0        4
#
#       yr_sold sale_type  saleprice
# 616      2008       WD      284700
# 1327     2008     ConLD      79000

# %%
# replace null values with 0

df['bsmt_half_bath'] = df['bsmt_half_bath'].fillna(0)

# %%
# get value count of fire places
# 1000 properties matches the number of null values in fireplace quality

df['fireplaces'].value_counts()
# Out:
# 0    1000
# 1     898
# 2     146
# 3       6
# 4       1
# Name: fireplaces, dtype: int64

# %%
# get unique values for fireplace quality 
# nan is misrepresented as null when it should represent no fire place

df['fireplace_qu'].unique()
# Out:
# array([nan, 'TA', 'Gd', 'Po', 'Ex', 'Fa'], dtype=object)

# %%
# replace fireplace_qu with NoF to represent no fireplace

df['fireplace_qu'] = df['fireplace_qu'].fillna('NoF')

# %%
# get value count on garage qual
# nan is mis represented as null when it should represent no garage

df['garage_qual'].value_counts()
# Out:
# TA    1832
# Fa      82
# Gd      18
# Ex       3
# Po       2
# Name: garage_qual, dtype: int64

# %%
2051 - 1832 - 82 - 18 - 3 - 2
# Out:
# 114

# %%
df['garage_finish'].value_counts()
# Out:
# Unf    849
# RFn    579
# Fin    509
# Name: garage_finish, dtype: int64

# %%
2051 - 849 -579 - 509
# Out:
# 114

# %% [markdown]
# There seems to be an agreeance between garage quality and garage finish that there are 114 properties without a garage. I will replace NA values with NoG for better comprehension and remove null value count.

# %%
# replace garage type with NoG to represent no garage

df['garage_type'] = df['garage_type'].fillna('NoG')

# %%
# replace garage finish with NoG to represent no garage

df['garage_finish'] = df['garage_finish'].fillna('NoG')

# %%
# replace garage qual with NoG to represent no garage

df['garage_qual'] = df['garage_qual'].fillna('NoG')

# %%
# replace garage cond with NoG to represent no garage

df['garage_cond'] = df['garage_cond'].fillna('NoG')

# %%
# get the null values of year garage was built

df['garage_yr_blt'].isnull().sum()
# Out:
# 114

# %% [markdown]
# The total number of values matches the amount of properties that were labeled with no garage.

# %%
# select the row with no garage cars value 
# this property has no garage and will replace with 0

df[df['garage_cars'].isnull()]
# Out:
#         id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 1712  2237  910201180           70        RM          50.0      9060   Pave
#
#      alley lot_shape land_contour utilities lot_config land_slope  \
# 1712   NaN       Reg          Lvl    AllPub     Inside        Gtl
#
#      neighborhood condition_1 condition_2 bldg_type house_style  overall_qual  \
# 1712       IDOTRR        Norm        Norm      1Fam      2Story             5
#
#       overall_cond  year_built  year_remod/add roof_style roof_matl  \
# 1712             6        1923            1999      Gable   CompShg
#
#      exterior_1st exterior_2nd mas_vnr_type  mas_vnr_area exter_qual  \
# 1712      Wd Sdng      Plywood         None           0.0         TA
#
#      exter_cond foundation bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  \
# 1712         TA     BrkTil        Gd        TA            No            ALQ
#
#       bsmtfin_sf_1 bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf  \
# 1712         548.0            Unf           0.0        311.0          859.0
#
#      heating heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# 1712    GasA         Ex           Y      SBrkr         942         886
#
#       low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 1712                0         1828             0.0             0.0          2
#
#       half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 1712          0              3              1           Gd              6
#
#      functional  fireplaces fireplace_qu garage_type  garage_yr_blt  \
# 1712        Typ           0          NoF      Detchd            NaN
#
#      garage_finish  garage_cars  garage_area garage_qual garage_cond  \
# 1712           NoG          NaN          NaN         NoG         NoG
#
#      paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  \
# 1712           Y           174              0             212           0
#
#       screen_porch  pool_area pool_qc  fence misc_feature  misc_val  mo_sold  \
# 1712             0          0     NaN  MnPrv          NaN         0        3
#
#       yr_sold sale_type  saleprice
# 1712     2007       WD      150909

# %%
# replace null value with 0 because there is no garage

df['garage_cars'] = df['garage_cars'].fillna(0)

# %%
# get value count of garage by car space, 114 should have 0

df['garage_cars'].value_counts()
# Out:
# 2.0    1136
# 1.0     524
# 3.0     263
# 0.0     114
# 4.0      13
# 5.0       1
# Name: garage_cars, dtype: int64

# %%
# get value count of garage area
# there should be 114 with area of 0 since they have no garage

df['garage_area'].value_counts(ascending=False)
# Out:
# 0.0       113
# 440.0      70
# 576.0      69
# 484.0      52
# 528.0      46
#          ...
# 406.0       1
# 309.0       1
# 580.0       1
# 1184.0      1
# 557.0       1
# Name: garage_area, Length: 514, dtype: int64

# %%
# replace null value with 0 because property does not have garage

df['garage_area'] = df['garage_area'].fillna(0)

# %%
# get value count of pool quality ratings
# data dictionary has NA labeled as No Pool which may be misrepresented as null value

df['pool_qc'].value_counts()
# Out:
# Gd    4
# Fa    2
# TA    2
# Ex    1
# Name: pool_qc, dtype: int64

# %%
# compare rating count and number of null values

2051 - 4 - 2 - 2 -1
# Out:
# 2042

# %%
# compare rating count and number of null values

df['pool_area'].value_counts()
# Out:
# 0      2042
# 561       1
# 519       1
# 800       1
# 738       1
# 648       1
# 576       1
# 480       1
# 368       1
# 228       1
# Name: pool_area, dtype: int64

# %% [markdown]
# There seems to be an agreeance with the number of null values and the properties with. no pool. I will replace the null values in pool_qc with NoP to represent no pool and remove the null values.

# %%
# replace null values with NoP to represent no pool

df['pool_qc'] = df['pool_qc'].fillna('NoP')

# %%
# get value count of fences
# data dictionary has NA labeled as no fence which may be misrepresented as null value

df['fence'].value_counts()
# Out:
# MnPrv    227
# GdPrv     83
# GdWo      80
# MnWw      10
# Name: fence, dtype: int64

# %%
# compare fence count and number of null values

2051 - 227 - 83 - 80 -10
# Out:
# 1651

# %%
# replace null values with NoF to represent no fence

df['fence'] = df['fence'].fillna('NoF')

# %%
# get value count of misc features
# data dictionary has NA labeled as none which may be misrepresented as null value

df['misc_feature'].value_counts()
# Out:
# Shed    56
# Gar2     4
# Othr     3
# TenC     1
# Elev     1
# Name: misc_feature, dtype: int64

# %%
# compare misc feature count and number of null values

2051 - 56 - 4 - 3 - 1 - 1
# Out:
# 1986

# %%
# replace null values with NoMF to represent no misc features

df['misc_feature'] = df['misc_feature'].fillna('NoMF')

# %%
# select rows with null values in total bsmt sf

df[df['total_bsmt_sf'].isnull()]
# Out:
#         id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 1327  1342  903230120           20        RM          99.0      5940   Pave
#
#      alley lot_shape land_contour utilities lot_config land_slope  \
# 1327   NaN       IR1          Lvl    AllPub        FR3        Gtl
#
#      neighborhood condition_1 condition_2 bldg_type house_style  overall_qual  \
# 1327      BrkSide       Feedr        Norm      1Fam      1Story             4
#
#       overall_cond  year_built  year_remod/add roof_style roof_matl  \
# 1327             7        1946            1950      Gable   CompShg
#
#      exterior_1st exterior_2nd mas_vnr_type  mas_vnr_area exter_qual  \
# 1327      MetalSd       CBlock         None           0.0         TA
#
#      exter_cond foundation bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  \
# 1327         TA      PConc       NoB       NoB           NaN            NaN
#
#       bsmtfin_sf_1 bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf  \
# 1327           NaN            NaN         47.96       567.72            NaN
#
#      heating heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# 1327    GasA         TA           Y      FuseA         896           0
#
#       low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 1327                0          896             0.0             0.0          1
#
#       half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 1327          0              2              1           TA              4
#
#      functional  fireplaces fireplace_qu garage_type  garage_yr_blt  \
# 1327        Typ           0          NoF      Detchd         1946.0
#
#      garage_finish  garage_cars  garage_area garage_qual garage_cond  \
# 1327           Unf          1.0        280.0          TA          TA
#
#      paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  \
# 1327           Y             0              0               0           0
#
#       screen_porch  pool_area pool_qc  fence misc_feature  misc_val  mo_sold  \
# 1327             0          0     NoP  MnPrv         NoMF         0        4
#
#       yr_sold sale_type  saleprice
# 1327     2008     ConLD      79000

# %%
# this selection has no basement 
# replace null value with 0

df['total_bsmt_sf'] = df['total_bsmt_sf'].fillna(0)

# %%
# get value count of alley

df['alley'].value_counts()
# Out:
# Grvl    85
# Pave    55
# Name: alley, dtype: int64

# %%
# compare to null values

2051 -85 -55
# Out:
# 1911

# %%
#replace null values with NoA to represent no alley access

df['alley'] = df['alley'].fillna('NoA')

# %%
# get value count of mas_vnr_type

df['mas_vnr_type'].value_counts()
# Out:
# None       1218
# BrkFace     630
# Stone       168
# BrkCmn       13
# Name: mas_vnr_type, dtype: int64

# %%
# get value count of basement exposure

df['bsmt_exposure'].value_counts()
# Out:
# No    1339
# Av     288
# Gd     203
# Mn     163
# Name: bsmt_exposure, dtype: int64

# %%
# compare to null values

2051 - 1339 - 288 - 203 - 163
# Out:
# 58

# %%
# replace null values with NoB to represent no basment
# data dictionary has NA labeled as no basement which may be misrepresented as null value

df['bsmt_exposure'] = df['bsmt_exposure'].fillna('NoB')

# %%
# get value count of basement finished area
# this number agrees with number of properties with no basment

df['bsmtfin_type_1'].value_counts()
# Out:
# GLQ    615
# Unf    603
# ALQ    293
# BLQ    200
# Rec    183
# LwQ    102
# Name: bsmtfin_type_1, dtype: int64

# %%
# replace null values with NoB to represent no basement
# data dictionary has NA labeled as no basement which may be misrepresented as null value

df['bsmtfin_type_1'] = df['bsmtfin_type_1'].fillna('NoB')

# %%
# select row with null values for bsmt finished in sq feet
# this property has no basement 

df[df['bsmtfin_sf_1'].isnull()]
# Out:
#         id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 1327  1342  903230120           20        RM          99.0      5940   Pave
#
#      alley lot_shape land_contour utilities lot_config land_slope  \
# 1327   NoA       IR1          Lvl    AllPub        FR3        Gtl
#
#      neighborhood condition_1 condition_2 bldg_type house_style  overall_qual  \
# 1327      BrkSide       Feedr        Norm      1Fam      1Story             4
#
#       overall_cond  year_built  year_remod/add roof_style roof_matl  \
# 1327             7        1946            1950      Gable   CompShg
#
#      exterior_1st exterior_2nd mas_vnr_type  mas_vnr_area exter_qual  \
# 1327      MetalSd       CBlock         None           0.0         TA
#
#      exter_cond foundation bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  \
# 1327         TA      PConc       NoB       NoB           NoB            NoB
#
#       bsmtfin_sf_1 bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf  \
# 1327           NaN            NaN         47.96       567.72            0.0
#
#      heating heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# 1327    GasA         TA           Y      FuseA         896           0
#
#       low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 1327                0          896             0.0             0.0          1
#
#       half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 1327          0              2              1           TA              4
#
#      functional  fireplaces fireplace_qu garage_type  garage_yr_blt  \
# 1327        Typ           0          NoF      Detchd         1946.0
#
#      garage_finish  garage_cars  garage_area garage_qual garage_cond  \
# 1327           Unf          1.0        280.0          TA          TA
#
#      paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  \
# 1327           Y             0              0               0           0
#
#       screen_porch  pool_area pool_qc  fence misc_feature  misc_val  mo_sold  \
# 1327             0          0     NoP  MnPrv         NoMF         0        4
#
#       yr_sold sale_type  saleprice
# 1327     2008     ConLD      79000

# %%
df['bsmtfin_sf_1'] = df['bsmtfin_sf_1'].fillna(0)

# %%
df['bsmtfin_type_2'].value_counts()
# Out:
# Unf    1749
# Rec      80
# LwQ      60
# BLQ      48
# ALQ      35
# GLQ      23
# Name: bsmtfin_type_2, dtype: int64

# %%
2051 - 1749 - 80 - 60 - 48 - 35 - 23
# Out:
# 56

# %%
# select row with null values for bsmt type 2
# all rows expect 1147 have no basement 

df[df['bsmtfin_type_2'].isnull()]
# Out:
#         id        pid  ms_subclass ms_zoning  lot_frontage  lot_area street  \
# 12     807  906226060           70        RL         120.0     26400   Pave
# 93     811  906226100           90        RL          64.0      7018   Pave
# 114    781  905228050           20        RL          69.0      9000   Pave
# 146    888  908128060           85        RL          64.0      7301   Pave
# 183   1554  910251050           20   A (agr)          80.0     14584   Pave
# 240   2740  905451050           20        RL          80.0     12048   Pave
# 249   2242  910206010           50        RM          64.0     11067   Pave
# 256   2745  905477010           20        RL          77.0      8335   Pave
# 390     84  532351140           90        RM          68.0      8930   Pave
# 437   1501  908201100           90        RL          65.0      6040   Pave
# 485    155  535327140           20        RL          60.0      7200   Pave
# 499    812  906226110           90        RL          64.0      7018   Pave
# 514   2082  905475520           30        RL          69.0     11515   Pave
# 580   1504  908204160           90        RL          74.0      6845   Pave
# 581    946  912251110           30   I (all)         109.0     21780   Grvl
# 616   1498  908154080           20        RL         123.0     47007   Pave
# 635   2904  923125030           20   A (agr)         125.0     31250   Pave
# 642    953  914476020           90        RL          75.0     10125   Pave
# 696    274  908102060           30        RL          67.0      8777   Pave
# 700    207  903454060          190        RM          70.0      5600   Pave
# 737    788  905402070           20        RL          69.0     15635   Pave
# 772    679  535451170           90        RL          60.0      7200   Pave
# 790   1205  534276190           20        RL          74.0      7785   Pave
# 794   1255  535375140           20        RL          60.0     10122   Pave
# 924    677  535450160           90        RL          60.0      8544   Pave
# 933   1375  904101170           50        RL          80.0     17120   Pave
# 954   2622  535451190           20        RL          60.0      7200   Pave
# 1007  1880  534252070           90        RL          69.0     10899   Pave
# 1022  2703  904301410           30        RL          55.0      8250   Pave
# 1049  2177  908152180           90        RL          69.0      9555   Pave
# 1089   709  902205010           30        RM          50.0      5925   Pave
# 1098  1260  535383100          190        RL          60.0     10800   Pave
# 1125  2626  535454050           90        RL          69.0      8544   Pave
# 1147   445  528142130           20        RL          85.0     10655   Pave
# 1157   897  908225370           50        RL          50.0      8405   Pave
# 1211  2893  916252170          120        RM          69.0      8239   Pave
# 1222  1326  902427045           20        RM          70.0     12702   Pave
# 1252   244  905478190           20        RL          60.0     11100   Pave
# 1256   813  906226120           90        RL          64.0      7018   Pave
# 1270  1569  914476080           90        RL          76.0     10260   Pave
# 1327  1342  903230120           20        RM          99.0      5940   Pave
# 1331   650  535353060           20        RL          75.0      9533   Pave
# 1377  2707  905101330           90        RL          72.0     10791   Pave
# 1387   787  905402060           20        RL          69.0     13680   Pave
# 1428  1902  534450090           20        RL          50.0      5000   Pave
# 1481  2701  904100170           20        RL         100.0     21370   Pave
# 1594  1502  908201110           90        RL          65.0      6012   Pave
# 1620   815  906226140           90        RL          64.0      7007   Pave
# 1681  1899  534429030           90        RL          70.0      9842   Pave
# 1684  2004  902427140           20        RM          52.0      8626   Pave
# 1686  2627  535454060           90        RL          60.0      8544   Pave
# 1859  2625  535454030           90        RL          60.0      8544   Pave
# 1875  2279  923202220           20        RL         200.0     43500   Pave
# 1889   810  906226090           90        RL          64.0      7018   Pave
# 1933  2338  527226010           60        RL          69.0     14762   Pave
# 2010  2880  911175410           30   C (all)          69.0     12366   Pave
#
#      alley lot_shape land_contour utilities lot_config land_slope  \
# 12     NoA       Reg          Bnk    AllPub        FR2        Gtl
# 93     NoA       Reg          Bnk    AllPub     Inside        Gtl
# 114    NoA       Reg          Lvl    AllPub     Corner        Gtl
# 146    NoA       Reg          Lvl    AllPub     Corner        Gtl
# 183    NoA       Reg          Low    AllPub     Inside        Mod
# 240    NoA       Reg          Lvl    AllPub     Inside        Gtl
# 249    NoA       Reg          Lvl    AllPub     Corner        Gtl
# 256    NoA       Reg          Lvl    AllPub     Corner        Gtl
# 390    NoA       Reg          Lvl    AllPub     Inside        Gtl
# 437    NoA       Reg          Lvl    AllPub     Inside        Gtl
# 485    NoA       Reg          Lvl    AllPub     Inside        Gtl
# 499    NoA       Reg          Bnk    AllPub     Inside        Gtl
# 514    NoA       IR1          Lvl    AllPub    CulDSac        Gtl
# 580    NoA       Reg          Lvl    AllPub     Inside        Gtl
# 581    NoA       Reg          Lvl    NoSewr     Inside        Gtl
# 616    NoA       IR1          Lvl    AllPub     Inside        Gtl
# 635    NoA       Reg          Lvl    AllPub     Inside        Gtl
# 642    NoA       Reg          Lvl    AllPub     Inside        Gtl
# 696    NoA       Reg          Lvl    AllPub     Inside        Mod
# 700    NoA       Reg          Lvl    AllPub     Inside        Gtl
# 737    NoA       IR1          Lvl    AllPub    CulDSac        Gtl
# 772    NoA       Reg          Lvl    AllPub     Inside        Gtl
# 790    NoA       IR1          Lvl    AllPub     Inside        Gtl
# 794    NoA       Reg          Lvl    AllPub     Inside        Gtl
# 924    NoA       Reg          Lvl    AllPub     Corner        Gtl
# 933    NoA       Reg          Lvl    AllPub     Inside        Gtl
# 954    NoA       Reg          Lvl    AllPub     Inside        Gtl
# 1007   NoA       IR1          Lvl    AllPub     Inside        Gtl
# 1022   NoA       Reg          Lvl    AllPub     Inside        Gtl
# 1049   NoA       IR1          Lvl    AllPub    CulDSac        Gtl
# 1089   NoA       Reg          Lvl    AllPub     Corner        Gtl
# 1098  Grvl       Reg          Lvl    AllPub     Inside        Gtl
# 1125   NoA       Reg          Lvl    AllPub     Inside        Gtl
# 1147   NoA       IR1          Lvl    AllPub     Inside        Gtl
# 1157   NoA       Reg          Lvl    AllPub     Inside        Gtl
# 1211   NoA       IR1          Lvl    AllPub     Inside        Gtl
# 1222   NoA       Reg          Lvl    AllPub     Inside        Gtl
# 1252   NoA       Reg          Low    AllPub     Inside        Gtl
# 1256   NoA       Reg          Lvl    AllPub     Inside        Gtl
# 1270   NoA       Reg          Lvl    AllPub     Inside        Gtl
# 1327   NoA       IR1          Lvl    AllPub        FR3        Gtl
# 1331   NoA       Reg          Lvl    AllPub     Inside        Gtl
# 1377   NoA       Reg          Lvl    AllPub     Inside        Gtl
# 1387   NoA       IR1          Lvl    AllPub    CulDSac        Gtl
# 1428   NoA       Reg          Low    AllPub     Inside        Mod
# 1481   NoA       Reg          Lvl    AllPub        FR2        Gtl
# 1594   NoA       Reg          Lvl    AllPub     Corner        Gtl
# 1620   NoA       Reg          Bnk    AllPub     Inside        Gtl
# 1681   NoA       Reg          Lvl    AllPub        FR2        Gtl
# 1684   NoA       Reg          Lvl    AllPub     Inside        Gtl
# 1686   NoA       Reg          Lvl    AllPub     Inside        Gtl
# 1859   NoA       Reg          Lvl    AllPub     Corner        Gtl
# 1875   NoA       Reg          Lvl    AllPub     Inside        Gtl
# 1889   NoA       Reg          Lvl    AllPub     Inside        Gtl
# 1933   NoA       IR2          Lvl    AllPub     Corner        Gtl
# 2010   NoA       Reg          Lvl    AllPub     Inside        Gtl
#
#      neighborhood condition_1 condition_2 bldg_type house_style  overall_qual  \
# 12        SawyerW       Feedr        Norm      1Fam      2Story             5
# 93        SawyerW        Norm        Norm    Duplex      1Story             5
# 114        Sawyer        Norm        Norm      1Fam      1Story             2
# 146       Edwards        Norm        Norm      1Fam      SFoyer             7
# 183        IDOTRR        Norm        Norm      1Fam      1Story             1
# 240       Edwards        Norm        Norm      1Fam      1Story             5
# 249        IDOTRR        Norm        Norm      1Fam      1.5Fin             2
# 256       Edwards        Norm        Norm      1Fam      1Story             5
# 390        Sawyer        RRAe        Norm    Duplex      1.5Fin             6
# 437       Edwards        Norm        Norm    Duplex      1Story             4
# 485         NAmes        Norm        Norm      1Fam      1Story             5
# 499       SawyerW        Norm        Norm    Duplex      1Story             5
# 514       Edwards        Norm        Norm      1Fam      1Story             4
# 580       Edwards        Norm        Norm    Duplex      1Story             4
# 581        IDOTRR        Norm        Norm      1Fam      1Story             2
# 616       Edwards        Norm        Norm      1Fam      1Story             5
# 635       Mitchel      Artery        Norm      1Fam      1Story             1
# 642       Mitchel        Norm        Norm    Duplex      1.5Fin             5
# 696       Edwards       Feedr        Norm      1Fam      1Story             3
# 700        IDOTRR        Norm        Norm    2fmCon      2Story             4
# 737       Edwards        Norm        Norm      1Fam      1Story             4
# 772         NAmes        Norm        Norm    Duplex      1Story             4
# 790         NAmes        Norm        Norm      1Fam      1Story             5
# 794       OldTown        Norm        Norm      1Fam      1Story             4
# 924         NAmes        Norm        Norm    Duplex      1Story             3
# 933       ClearCr       Feedr        Norm      1Fam      1.5Fin             4
# 954         NAmes        Norm        Norm      1Fam      1Story             5
# 1007        NAmes        Norm        Norm    Duplex      1Story             4
# 1022      Edwards        Norm        Norm      1Fam      1Story             5
# 1049      Edwards        Norm        Norm    Duplex      2Story             5
# 1089      OldTown        Norm        Norm      1Fam      1Story             2
# 1098      OldTown        Norm        Norm    2fmCon      2Story             4
# 1125        NAmes        Norm        Norm    Duplex      1Story             3
# 1147      NridgHt        Norm        Norm      1Fam      1Story             8
# 1157      Edwards        Norm        Norm      1Fam      1.5Fin             4
# 1211      GrnHill        Norm        Norm    TwnhsE      1Story             7
# 1222      OldTown        Norm        Norm      1Fam      1Story             5
# 1252      Edwards        Norm        Norm      1Fam      1Story             4
# 1256      SawyerW       Feedr        Norm    Duplex      2Story             5
# 1270      Mitchel        Norm        Norm    Duplex      2Story             5
# 1327      BrkSide       Feedr        Norm      1Fam      1Story             4
# 1331        NAmes        Norm        Norm      1Fam      1Story             5
# 1377       Sawyer        Norm        Norm    Duplex      1Story             4
# 1387      Edwards        Norm        Norm      1Fam      1Story             3
# 1428      BrkSide        Norm        Norm      1Fam      1Story             1
# 1481       Sawyer        Norm        Norm      1Fam      1Story             5
# 1594      Edwards        Norm        Norm    Duplex      1Story             4
# 1620      SawyerW        Norm        Norm    Duplex      1Story             5
# 1681        NAmes        Norm        Norm    Duplex      1Story             4
# 1684      OldTown        Norm        Norm      1Fam      1Story             4
# 1686        NAmes        Norm        Norm    Duplex      1Story             3
# 1859        NAmes        Norm        Norm    Duplex      1Story             3
# 1875      Mitchel      Artery        Norm      1Fam      1Story             3
# 1889      SawyerW       Feedr        Norm    Duplex      2Story             5
# 1933      Gilbert       Feedr        Norm      1Fam      2Story             5
# 2010       IDOTRR       Feedr        Norm      1Fam      1Story             3
#
#       overall_cond  year_built  year_remod/add roof_style roof_matl  \
# 12               7        1880            2007      Gable   CompShg
# 93               5        1979            1979      Gable   CompShg
# 114              2        1947            1950      Gable   CompShg
# 146              5        2003            2003      Gable   CompShg
# 183              5        1952            1952      Gable   CompShg
# 240              6        1952            2002      Gable   CompShg
# 249              4        1939            1950      Gable   CompShg
# 256              5        1954            1954      Gable   CompShg
# 390              5        1978            1978      Gable   CompShg
# 437              5        1955            1955      Gable   CompShg
# 485              7        1955            2007      Gable   CompShg
# 499              5        1979            1979      Gable   CompShg
# 514              5        1958            1994      Gable   CompShg
# 580              5        1955            1955      Gable   CompShg
# 581              4        1910            1950      Gable   CompShg
# 616              7        1959            1996      Gable   CompShg
# 635              3        1951            1951      Gable   CompShg
# 642              5        1977            1977      Gable   CompShg
# 696              6        1945            2007      Gable   CompShg
# 700              5        1930            1950        Hip   CompShg
# 737              5        1954            1954      Gable   CompShg
# 772              5        1949            1950      Gable   CompShg
# 790              5        1956            1956      Gable   CompShg
# 794              6        1948            1950      Gable   CompShg
# 924              4        1950            1950      Gable   CompShg
# 933              4        1959            1959      Gable   CompShg
# 954              7        1950            1950        Hip   CompShg
# 1007             5        1964            1964      Gable   CompShg
# 1022             7        1935            1950      Gable   CompShg
# 1049             6        1979            1979      Gable   CompShg
# 1089             4        1940            1950      Gable   CompShg
# 1098             7        1900            2000      Gable   CompShg
# 1125             4        1949            1950      Gable   CompShg
# 1147             5        2003            2004      Gable   CompShg
# 1157             3        1945            1950      Gable   CompShg
# 1211             5        1986            1986      Gable   CompShg
# 1222             5        1956            1956      Gable   CompShg
# 1252             7        1946            2006      Gable   CompShg
# 1256             5        1979            1979      Gable   CompShg
# 1270             4        1976            1976      Gable   CompShg
# 1327             7        1946            1950      Gable   CompShg
# 1331             5        1953            1953        Hip   CompShg
# 1377             5        1967            1967      Gable   CompShg
# 1387             5        1955            1955        Hip   CompShg
# 1428             3        1946            1950      Gable   CompShg
# 1481             5        1950            1950      Gable   CompShg
# 1594             5        1955            1955      Gable   CompShg
# 1620             5        1979            1979      Gable   CompShg
# 1681             5        1962            1962      Gable   CompShg
# 1684             6        1956            1956      Gable   CompShg
# 1686             4        1950            1950      Gable   CompShg
# 1859             4        1950            1950      Gable   CompShg
# 1875             5        1953            1953      Gable   CompShg
# 1889             5        1979            1979      Gable   CompShg
# 1933             6        1948            1950      Gable   CompShg
# 2010             5        1945            1950      Gable   CompShg
#
#      exterior_1st exterior_2nd mas_vnr_type  mas_vnr_area exter_qual  \
# 12        HdBoard      HdBoard         None           0.0         Gd
# 93        HdBoard      HdBoard         None           0.0         TA
# 114       Wd Sdng      Wd Sdng         None           0.0         TA
# 146       HdBoard      HdBoard      BrkFace         500.0         Gd
# 183       AsbShng      VinylSd         None           0.0         Fa
# 240       Wd Sdng      Wd Sdng      BrkFace         232.0         TA
# 249       MetalSd      MetalSd         None           0.0         TA
# 256       Wd Sdng      Wd Sdng         None           0.0         TA
# 390       VinylSd      VinylSd         None           0.0         TA
# 437       AsbShng      Plywood         None           0.0         TA
# 485       VinylSd      VinylSd         None           0.0         TA
# 499       Plywood      Plywood         None           0.0         TA
# 514       HdBoard      HdBoard         None           0.0         TA
# 580       WdShing      Wd Shng       BrkCmn          58.0         TA
# 581       Wd Sdng      Wd Sdng         None           0.0         Fa
# 616       Plywood      Plywood         None           0.0         TA
# 635        CBlock      VinylSd         None           0.0         TA
# 642       Plywood      Plywood         None           0.0         TA
# 696       VinylSd      VinylSd         None           0.0         TA
# 700       VinylSd      Wd Shng         None           0.0         Fa
# 737       VinylSd      VinylSd         None           0.0         TA
# 772       BrkFace        Stone         None           0.0         TA
# 790       HdBoard      HdBoard         None           0.0         TA
# 794       MetalSd      MetalSd         None           0.0         TA
# 924       BrkFace      BrkFace         None           0.0         TA
# 933       WdShing      Plywood         None           0.0         TA
# 954       Wd Sdng      Wd Sdng         None           0.0         TA
# 1007      HdBoard      HdBoard         None           0.0         TA
# 1022      Wd Sdng      Wd Sdng         None           0.0         TA
# 1049      Plywood      Plywood         None           0.0         TA
# 1089      MetalSd      MetalSd         None           0.0         TA
# 1098      MetalSd      MetalSd         None           0.0         TA
# 1125       Stucco       Stucco      BrkFace         340.0         TA
# 1147      VinylSd      VinylSd      BrkFace         296.0         Gd
# 1157      WdShing      Wd Shng         None           0.0         TA
# 1211      BrkFace      Wd Sdng         None           0.0         Gd
# 1222      BrkFace      BrkFace         None           0.0         TA
# 1252      MetalSd      MetalSd         None           0.0         TA
# 1256      Plywood      Plywood         None           0.0         TA
# 1270      Plywood      Plywood         None           0.0         TA
# 1327      MetalSd       CBlock         None           0.0         TA
# 1331      Wd Sdng      Wd Sdng      BrkFace         140.0         TA
# 1377      MetalSd      MetalSd         None           0.0         TA
# 1387      BrkFace      Wd Sdng         None           0.0         TA
# 1428      VinylSd      VinylSd         None           0.0         Fa
# 1481      Wd Sdng      MetalSd         None           0.0         TA
# 1594      AsbShng      Plywood         None           0.0         TA
# 1620      HdBoard      HdBoard         None           0.0         TA
# 1681      HdBoard      HdBoard         None           0.0         TA
# 1684      MetalSd      MetalSd         None           1.0         TA
# 1686       Stucco        Stone         None           0.0         TA
# 1859      BrkFace        Stone         None           0.0         TA
# 1875      MetalSd      MetalSd         None           0.0         TA
# 1889      HdBoard      HdBoard         None           0.0         TA
# 1933      Plywood      Plywood         None           0.0         TA
# 2010      Wd Sdng      Wd Sdng         None           0.0         TA
#
#      exter_cond foundation bsmt_qual bsmt_cond bsmt_exposure bsmtfin_type_1  \
# 12           TA      PConc       NoB       NoB           NoB            NoB
# 93           TA       Slab       NoB       NoB           NoB            NoB
# 114          TA       Slab       NoB       NoB           NoB            NoB
# 146          TA       Slab       NoB       NoB           NoB            NoB
# 183          Po       Slab       NoB       NoB           NoB            NoB
# 240          TA       Slab       NoB       NoB           NoB            NoB
# 249          TA     BrkTil       NoB       NoB           NoB            NoB
# 256          TA       Slab       NoB       NoB           NoB            NoB
# 390          TA       Slab       NoB       NoB           NoB            NoB
# 437          TA      PConc       NoB       NoB           NoB            NoB
# 485          TA       Slab       NoB       NoB           NoB            NoB
# 499          TA       Slab       NoB       NoB           NoB            NoB
# 514          TA       Slab       NoB       NoB           NoB            NoB
# 580          TA       Slab       NoB       NoB           NoB            NoB
# 581          Fa     CBlock       NoB       NoB           NoB            NoB
# 616          TA       Slab       NoB       NoB           NoB            NoB
# 635          Fa     CBlock       NoB       NoB           NoB            NoB
# 642          TA     CBlock       NoB       NoB           NoB            NoB
# 696          Gd     CBlock       NoB       NoB           NoB            NoB
# 700          Fa       Slab       NoB       NoB           NoB            NoB
# 737          TA     CBlock       NoB       NoB           NoB            NoB
# 772          TA       Slab       NoB       NoB           NoB            NoB
# 790          TA       Slab       NoB       NoB           NoB            NoB
# 794          TA       Slab       NoB       NoB           NoB            NoB
# 924          TA       Slab       NoB       NoB           NoB            NoB
# 933          TA     CBlock       NoB       NoB           NoB            NoB
# 954          TA     CBlock       NoB       NoB           NoB            NoB
# 1007         TA       Slab       NoB       NoB           NoB            NoB
# 1022         TA       Slab       NoB       NoB           NoB            NoB
# 1049         TA       Slab       NoB       NoB           NoB            NoB
# 1089         Gd     BrkTil       NoB       NoB           NoB            NoB
# 1098         TA     BrkTil       NoB       NoB           NoB            NoB
# 1125         TA       Slab       NoB       NoB           NoB            NoB
# 1147         TA      PConc        Gd        TA            No            GLQ
# 1157         TA       Slab       NoB       NoB           NoB            NoB
# 1211         TA     CBlock       NoB       NoB           NoB            NoB
# 1222         TA      PConc       NoB       NoB           NoB            NoB
# 1252         TA     CBlock       NoB       NoB           NoB            NoB
# 1256         TA       Slab       NoB       NoB           NoB            NoB
# 1270         TA     CBlock       NoB       NoB           NoB            NoB
# 1327         TA      PConc       NoB       NoB           NoB            NoB
# 1331         TA       Slab       NoB       NoB           NoB            NoB
# 1377         TA       Slab       NoB       NoB           NoB            NoB
# 1387         TA       Slab       NoB       NoB           NoB            NoB
# 1428         Fa       Slab       NoB       NoB           NoB            NoB
# 1481         TA       Slab       NoB       NoB           NoB            NoB
# 1594         Fa      PConc       NoB       NoB           NoB            NoB
# 1620         TA       Slab       NoB       NoB           NoB            NoB
# 1681         TA       Slab       NoB       NoB           NoB            NoB
# 1684         TA     CBlock       NoB       NoB           NoB            NoB
# 1686         TA     CBlock       NoB       NoB           NoB            NoB
# 1859         TA       Slab       NoB       NoB           NoB            NoB
# 1875         TA     CBlock       NoB       NoB           NoB            NoB
# 1889         TA       Slab       NoB       NoB           NoB            NoB
# 1933         TA       Slab       NoB       NoB           NoB            NoB
# 2010         TA       Slab       NoB       NoB           NoB            NoB
#
#       bsmtfin_sf_1 bsmtfin_type_2  bsmtfin_sf_2  bsmt_unf_sf  total_bsmt_sf  \
# 12             0.0            NaN          0.00         0.00            0.0
# 93             0.0            NaN          0.00         0.00            0.0
# 114            0.0            NaN          0.00         0.00            0.0
# 146            0.0            NaN          0.00         0.00            0.0
# 183            0.0            NaN          0.00         0.00            0.0
# 240            0.0            NaN          0.00         0.00            0.0
# 249            0.0            NaN          0.00         0.00            0.0
# 256            0.0            NaN          0.00         0.00            0.0
# 390            0.0            NaN          0.00         0.00            0.0
# 437            0.0            NaN          0.00         0.00            0.0
# 485            0.0            NaN          0.00         0.00            0.0
# 499            0.0            NaN          0.00         0.00            0.0
# 514            0.0            NaN          0.00         0.00            0.0
# 580            0.0            NaN          0.00         0.00            0.0
# 581            0.0            NaN          0.00         0.00            0.0
# 616            0.0            NaN          0.00         0.00            0.0
# 635            0.0            NaN          0.00         0.00            0.0
# 642            0.0            NaN          0.00         0.00            0.0
# 696            0.0            NaN          0.00         0.00            0.0
# 700            0.0            NaN          0.00         0.00            0.0
# 737            0.0            NaN          0.00         0.00            0.0
# 772            0.0            NaN          0.00         0.00            0.0
# 790            0.0            NaN          0.00         0.00            0.0
# 794            0.0            NaN          0.00         0.00            0.0
# 924            0.0            NaN          0.00         0.00            0.0
# 933            0.0            NaN          0.00         0.00            0.0
# 954            0.0            NaN          0.00         0.00            0.0
# 1007           0.0            NaN          0.00         0.00            0.0
# 1022           0.0            NaN          0.00         0.00            0.0
# 1049           0.0            NaN          0.00         0.00            0.0
# 1089           0.0            NaN          0.00         0.00            0.0
# 1098           0.0            NaN          0.00         0.00            0.0
# 1125           0.0            NaN          0.00         0.00            0.0
# 1147        1124.0            NaN        479.00      1603.00         3206.0
# 1157           0.0            NaN          0.00         0.00            0.0
# 1211           0.0            NaN          0.00         0.00            0.0
# 1222           0.0            NaN          0.00         0.00            0.0
# 1252           0.0            NaN          0.00         0.00            0.0
# 1256           0.0            NaN          0.00         0.00            0.0
# 1270           0.0            NaN          0.00         0.00            0.0
# 1327           0.0            NaN         47.96       567.72            0.0
# 1331           0.0            NaN          0.00         0.00            0.0
# 1377           0.0            NaN          0.00         0.00            0.0
# 1387           0.0            NaN          0.00         0.00            0.0
# 1428           0.0            NaN          0.00         0.00            0.0
# 1481           0.0            NaN          0.00         0.00            0.0
# 1594           0.0            NaN          0.00         0.00            0.0
# 1620           0.0            NaN          0.00         0.00            0.0
# 1681           0.0            NaN          0.00         0.00            0.0
# 1684           0.0            NaN          0.00         0.00            0.0
# 1686           0.0            NaN          0.00         0.00            0.0
# 1859           0.0            NaN          0.00         0.00            0.0
# 1875           0.0            NaN          0.00         0.00            0.0
# 1889           0.0            NaN          0.00         0.00            0.0
# 1933           0.0            NaN          0.00         0.00            0.0
# 2010           0.0            NaN          0.00         0.00            0.0
#
#      heating heating_qc central_air electrical  1st_flr_sf  2nd_flr_sf  \
# 12      GasA         Ex           Y      SBrkr        1288         728
# 93      GasA         TA           Y      SBrkr        1535           0
# 114     GasA         Fa           N      SBrkr         660           0
# 146     GasA         Ex           Y      SBrkr         495        1427
# 183     Wall         Po           N      FuseA         733           0
# 240     GasA         Gd           Y      SBrkr        1488           0
# 249     GasA         Ex           Y      SBrkr         640           0
# 256     GasA         Gd           Y      SBrkr        1124           0
# 390     GasA         TA           Y      SBrkr        1318         584
# 437     GasA         TA           N      FuseP        1152           0
# 485     GasA         Ex           Y      SBrkr         827           0
# 499     GasA         TA           Y      SBrkr        1535           0
# 514     GasA         TA           N      SBrkr         943           0
# 580     GasA         TA           N      FuseF        1152           0
# 581     GasA         TA           N      FuseA         810           0
# 616     GasA         TA           Y      SBrkr        3820           0
# 635     GasA         TA           Y      FuseA        1600           0
# 642     GasA         TA           Y      SBrkr        1302         432
# 696     GasA         TA           N      SBrkr         640           0
# 700     GasA         Fa           N      SBrkr         372         720
# 737     GasA         TA           Y      SBrkr        1383           0
# 772     Wall         Fa           N      FuseF        1040           0
# 790     GasA         TA           Y      SBrkr        1014           0
# 794     GasA         TA           N      SBrkr         869           0
# 924     Wall         Fa           N      FuseA        1040           0
# 933     GasA         TA           Y      SBrkr        1120         468
# 954     GasA         TA           Y      FuseF        1040           0
# 1007    GasA         TA           N      SBrkr        1224           0
# 1022    GasA         TA           N      SBrkr        1032           0
# 1049    GasA         TA           Y      SBrkr        1100        1133
# 1089    GasA         Fa           N      FuseA         612           0
# 1098    GasA         TA           N      FuseA         694         600
# 1125    Wall         Fa           N      FuseA        1040           0
# 1147    GasA         Ex           Y      SBrkr        1629           0
# 1157    Wall         TA           N      FuseF        1088         441
# 1211    GasA         Gd           Y      SBrkr        1295           0
# 1222    GasA         Gd           Y      FuseA         882           0
# 1252    GasA         Ex           Y      SBrkr         930           0
# 1256    GasA         TA           Y      SBrkr        1120        1120
# 1270    GasA         TA           Y      SBrkr         936         936
# 1327    GasA         TA           Y      FuseA         896           0
# 1331    GasA         TA           Y      FuseA        1210           0
# 1377    GasA         TA           Y      SBrkr        1296           0
# 1387    GasA         Ex           Y      FuseA        1733           0
# 1428    GasA         Fa           N      FuseF         334           0
# 1481    GasA         TA           Y      FuseA        1640           0
# 1594    GasA         TA           N      SBrkr        1152           0
# 1620    GasA         TA           Y      SBrkr        1513           0
# 1681    GasA         TA           Y      SBrkr        1224           0
# 1684    GasA         Gd           Y      SBrkr         968           0
# 1686    GasA         Gd           N      FuseF        1040           0
# 1859    Wall         Fa           N      FuseF        1040           0
# 1875    GasA         Ex           Y      SBrkr        2034           0
# 1889    GasA         TA           Y      SBrkr        1114        1114
# 1933    GasA         Gd           Y      SBrkr        1547         720
# 2010    GasA         TA           N      SBrkr         729           0
#
#       low_qual_fin_sf  gr_liv_area  bsmt_full_bath  bsmt_half_bath  full_bath  \
# 12                  0         2016             0.0             0.0          1
# 93                  0         1535             0.0             0.0          2
# 114                 0          660             0.0             0.0          1
# 146                 0         1922             0.0             0.0          3
# 183                 0          733             0.0             0.0          1
# 240                 0         1488             0.0             0.0          1
# 249               205          845             0.0             0.0          1
# 256                 0         1124             0.0             0.0          1
# 390                 0         1902             0.0             0.0          2
# 437                 0         1152             0.0             0.0          2
# 485                 0          827             0.0             0.0          1
# 499                 0         1535             0.0             0.0          2
# 514                 0          943             0.0             0.0          1
# 580                 0         1152             0.0             0.0          2
# 581                 0          810             0.0             0.0          1
# 616                 0         3820             0.0             0.0          3
# 635                 0         1600             0.0             0.0          1
# 642                 0         1734             0.0             0.0          2
# 696                 0          640             0.0             0.0          1
# 700                 0         1092             0.0             0.0          2
# 737                 0         1383             0.0             0.0          1
# 772                 0         1040             0.0             0.0          2
# 790                 0         1014             0.0             0.0          1
# 794                 0          869             0.0             0.0          1
# 924                 0         1040             0.0             0.0          2
# 933                 0         1588             0.0             0.0          2
# 954                 0         1040             0.0             0.0          1
# 1007                0         1224             0.0             0.0          2
# 1022                0         1032             0.0             0.0          1
# 1049                0         2233             0.0             0.0          2
# 1089                0          612             0.0             0.0          1
# 1098                0         1294             0.0             0.0          2
# 1125                0         1040             0.0             0.0          2
# 1147                0         1629             1.0             0.0          2
# 1157                0         1529             0.0             0.0          2
# 1211                0         1295             0.0             0.0          2
# 1222                0          882             0.0             0.0          1
# 1252                0          930             0.0             0.0          1
# 1256                0         2240             0.0             0.0          2
# 1270                0         1872             0.0             0.0          2
# 1327                0          896             0.0             0.0          1
# 1331                0         1210             0.0             0.0          1
# 1377                0         1296             0.0             0.0          2
# 1387                0         1733             0.0             0.0          2
# 1428                0          334             0.0             0.0          1
# 1481                0         1640             0.0             0.0          1
# 1594                0         1152             0.0             0.0          2
# 1620                0         1513             0.0             0.0          2
# 1681                0         1224             0.0             0.0          2
# 1684                0          968             0.0             0.0          1
# 1686                0         1040             0.0             0.0          2
# 1859                0         1040             0.0             0.0          2
# 1875                0         2034             0.0             0.0          1
# 1889                0         2228             0.0             0.0          2
# 1933               53         2320             0.0             0.0          2
# 2010                0          729             0.0             0.0          1
#
#       half_bath  bedroom_abvgr  kitchen_abvgr kitchen_qual  totrms_abvgrd  \
# 12            0              4              1           TA              7
# 93            0              4              2           TA              8
# 114           0              2              1           Fa              5
# 146           0              4              1           Gd              7
# 183           0              2              1           Fa              4
# 240           0              3              1           TA              7
# 249           0              1              1           TA              4
# 256           0              3              1           TA              5
# 390           0              4              2           TA              8
# 437           0              2              2           Fa              6
# 485           0              2              1           TA              5
# 499           0              4              2           TA              8
# 514           0              3              1           Gd              5
# 580           0              2              2           TA              6
# 581           0              1              1           TA              4
# 616           1              5              1           Ex             11
# 635           1              3              1           TA              6
# 642           0              4              2           Gd              8
# 696           0              2              1           TA              5
# 700           0              3              2           Fa              7
# 737           0              2              1           TA              6
# 772           0              2              2           TA              6
# 790           0              2              1           TA              6
# 794           0              1              1           TA              3
# 924           0              2              2           TA              6
# 933           0              4              1           TA              7
# 954           0              2              1           TA              5
# 1007          0              2              2           TA              8
# 1022          0              2              1           TA              6
# 1049          1              5              2           TA             11
# 1089          0              1              1           TA              4
# 1098          0              3              2           TA              7
# 1125          0              2              2           TA              6
# 1147          0              3              1           Gd              7
# 1157          0              4              1           TA              9
# 1211          0              2              1           Gd              5
# 1222          0              2              1           TA              4
# 1252          0              2              1           Gd              6
# 1256          0              6              2           TA             12
# 1270          2              4              2           TA              8
# 1327          0              2              1           TA              4
# 1331          1              2              1           TA              7
# 1377          0              2              2           TA              6
# 1387          0              4              1           TA              8
# 1428          0              1              1           Fa              2
# 1481          0              3              1           TA              7
# 1594          0              2              2           TA              6
# 1620          0              4              2           TA              8
# 1681          0              2              2           TA              6
# 1684          0              2              1           TA              5
# 1686          0              2              2           TA              6
# 1859          0              2              2           TA              6
# 1875          0              2              1           TA              9
# 1889          0              6              2           TA              8
# 1933          0              2              1           TA              7
# 2010          0              2              1           TA              5
#
#      functional  fireplaces fireplace_qu garage_type  garage_yr_blt  \
# 12          Mod           1           TA      Attchd         1900.0
# 93          Typ           0          NoF      Attchd         1979.0
# 114        Min2           0          NoF         NoG            NaN
# 146         Typ           1           Ex     BuiltIn         2003.0
# 183         Sal           0          NoF      Attchd         1952.0
# 240         Typ           1           Ex      Attchd         2002.0
# 249        Maj2           0          NoF      Detchd         1950.0
# 256        Min2           1           Gd         NoG            NaN
# 390         Typ           0          NoF      Attchd         1978.0
# 437         Typ           0          NoF         NoG            NaN
# 485         Mod           1           Po      Detchd         1967.0
# 499         Typ           0          NoF      Attchd         1979.0
# 514        Min2           0          NoF      Detchd         1958.0
# 580         Typ           0          NoF         NoG            NaN
# 581        Min1           0          NoF      Detchd         1975.0
# 616         Typ           2           Gd      Attchd         1959.0
# 635         Mod           0          NoF      Attchd         1951.0
# 642         Typ           0          NoF      Attchd         1977.0
# 696        Min1           0          NoF      Detchd         1945.0
# 700         Mod           0          NoF         NoG            NaN
# 737         Mod           0          NoF      Attchd         1980.0
# 772         Typ           0          NoF      Detchd         1956.0
# 790         Typ           0          NoF      Attchd         1956.0
# 794         Typ           0          NoF      Detchd         1948.0
# 924         Typ           0          NoF      Detchd         1987.0
# 933        Min2           1           Gd      Detchd         1991.0
# 954         Typ           0          NoF      Detchd         1950.0
# 1007        Typ           0          NoF     CarPort         1964.0
# 1022        Typ           1           TA      Detchd         1939.0
# 1049        Typ           0          NoF      Attchd         1979.0
# 1089        Typ           0          NoF      Detchd         1965.0
# 1098        Typ           0          NoF         NoG            NaN
# 1125        Typ           0          NoF      Detchd         1949.0
# 1147        Typ           1           Gd      Attchd         2003.0
# 1157        Mod           0          NoF      Detchd         1945.0
# 1211        Typ           0          NoF      Attchd         1986.0
# 1222        Typ           0          NoF      Detchd         1956.0
# 1252        Typ           0          NoF      Detchd         1946.0
# 1256        Typ           0          NoF      Detchd         1979.0
# 1270        Typ           0          NoF      Attchd         1976.0
# 1327        Typ           0          NoF      Detchd         1946.0
# 1331        Typ           0          NoF      Attchd         1953.0
# 1377        Typ           0          NoF     CarPort         1967.0
# 1387       Min2           1           Gd      Attchd         1955.0
# 1428        Typ           0          NoF         NoG            NaN
# 1481       Min1           1           Gd      Attchd         1950.0
# 1594        Typ           0          NoF         NoG            NaN
# 1620        Typ           0          NoF      Attchd         1979.0
# 1681        Typ           0          NoF     CarPort         1962.0
# 1684        Typ           0          NoF      Attchd         1956.0
# 1686        Typ           0          NoF      Detchd         1949.0
# 1859        Typ           0          NoF      Detchd         1950.0
# 1875       Min1           0          NoF      2Types         1953.0
# 1889        Typ           0          NoF      Detchd         1979.0
# 1933        Typ           1           TA      Attchd         1979.0
# 2010        Mod           0          NoF         NoG            NaN
#
#      garage_finish  garage_cars  garage_area garage_qual garage_cond  \
# 12             Unf          2.0        576.0          TA          TA
# 93             Unf          2.0        400.0          TA          TA
# 114            NoG          0.0          0.0         NoG         NoG
# 146            RFn          2.0        672.0          TA          TA
# 183            Unf          2.0        487.0          Fa          Po
# 240            RFn          2.0        569.0          TA          TA
# 249            Unf          1.0        256.0          TA          Fa
# 256            NoG          0.0          0.0         NoG         NoG
# 390            Unf          2.0        539.0          TA          TA
# 437            NoG          0.0          0.0         NoG         NoG
# 485            Unf          1.0        392.0          TA          TA
# 499            Unf          2.0        400.0          TA          TA
# 514            Unf          1.0        308.0          TA          TA
# 580            NoG          0.0          0.0         NoG         NoG
# 581            Unf          1.0        280.0          TA          TA
# 616            Unf          2.0        624.0          TA          TA
# 635            Unf          1.0        270.0          Fa          TA
# 642            Unf          2.0        539.0          TA          TA
# 696            Unf          1.0        240.0          TA          TA
# 700            NoG          0.0          0.0         NoG         NoG
# 737            Unf          2.0        498.0          Fa          TA
# 772            Unf          2.0        420.0          TA          TA
# 790            RFn          1.0        267.0          TA          TA
# 794            Unf          1.0        390.0          Fa          TA
# 924            Unf          2.0        400.0          TA          TA
# 933            Fin          2.0        680.0          TA          TA
# 954            Unf          2.0        625.0          TA          TA
# 1007           Unf          3.0        530.0          TA          TA
# 1022           Unf          1.0        260.0          TA          TA
# 1049           Fin          2.0        579.0          TA          Gd
# 1089           Unf          1.0        308.0          TA          Fa
# 1098           NoG          0.0          0.0         NoG         NoG
# 1125           Unf          2.0        400.0          TA          TA
# 1147           RFn          3.0        880.0          TA          TA
# 1157           Unf          1.0        240.0          TA          TA
# 1211           RFn          1.0        312.0          TA          TA
# 1222           Unf          1.0        308.0          TA          TA
# 1252           Unf          1.0        308.0          TA          TA
# 1256           Unf          2.0        528.0          TA          TA
# 1270           Unf          2.0        484.0          TA          TA
# 1327           Unf          1.0        280.0          TA          TA
# 1331           Fin          1.0        616.0          TA          TA
# 1377           Unf          2.0        516.0          TA          TA
# 1387           Unf          2.0        452.0          TA          TA
# 1428           NoG          0.0          0.0         NoG         NoG
# 1481           RFn          2.0        394.0          TA          TA
# 1594           NoG          0.0          0.0         NoG         NoG
# 1620           Unf          2.0        400.0          TA          TA
# 1681           Unf          2.0        462.0          TA          TA
# 1684           Unf          1.0        331.0          Fa          TA
# 1686           Unf          2.0        400.0          TA          TA
# 1859           Unf          2.0        400.0          TA          Fa
# 1875           RFn          4.0       1041.0          TA          TA
# 1889           Unf          2.0        720.0          TA          TA
# 1933           Unf          2.0        672.0          TA          TA
# 2010           NoG          0.0          0.0         NoG         NoG
#
#      paved_drive  wood_deck_sf  open_porch_sf  enclosed_porch  3ssn_porch  \
# 12             P             0              0               0           0
# 93             Y             0              0               0           0
# 114            N             0              0             100           0
# 146            Y             0              0             177           0
# 183            N             0              0               0           0
# 240            Y             0            189              36           0
# 249            N            48              0               0           0
# 256            N             0             36             190           0
# 390            Y             0              0               0           0
# 437            N             0              0               0           0
# 485            Y             0              0               0           0
# 499            Y             0              0               0           0
# 514            N             0              0              60           0
# 580            N             0              0               0           0
# 581            N           119             24               0           0
# 616            Y             0            372               0           0
# 635            N             0              0             135           0
# 642            Y             0              0               0           0
# 696            N             0              0               0           0
# 700            N             0              0               0           0
# 737            Y             0              0              90           0
# 772            Y             0              0               0           0
# 790            Y             0              0              40           0
# 794            N             0              0              66           0
# 924            Y             0              0               0           0
# 933            N             0             59               0           0
# 954            Y             0              0               0           0
# 1007           Y             0              0               0           0
# 1022           Y             0              0             121           0
# 1049           Y             0              0               0           0
# 1089           N             0              0              25           0
# 1098           N           220            114             210           0
# 1125           Y             0              0               0           0
# 1147           Y             0              0               0           0
# 1157           N            92              0             185           0
# 1211           Y             0              0               0           0
# 1222           Y             0             45               0           0
# 1252           Y             0              0               0           0
# 1256           Y           154              0               0           0
# 1270           Y             0              0               0           0
# 1327           Y             0              0               0           0
# 1331           Y           208              0             100           0
# 1377           Y             0              0               0           0
# 1387           Y             0              0               0           0
# 1428           N             0              0               0           0
# 1481           Y             0              0             225           0
# 1594           N             0              0               0           0
# 1620           Y             0              0               0           0
# 1681           Y             0              0               0           0
# 1684           Y             0              0               0           0
# 1686           Y             0              0               0           0
# 1859           Y             0              0               0           0
# 1875           N           483            266               0           0
# 1889           Y            73              0               0           0
# 1933           P           120            144               0           0
# 2010           N             0              0              23           0
#
#       screen_porch  pool_area pool_qc  fence misc_feature  misc_val  mo_sold  \
# 12               0          0     NoP    NoF         NoMF         0        6
# 93               0          0     NoP  GdPrv         NoMF         0        6
# 114              0          0     NoP    NoF         NoMF         0        6
# 146              0          0     NoP    NoF         NoMF         0        7
# 183              0          0     NoP    NoF         NoMF         0        2
# 240            348          0     NoP    NoF         NoMF         0        4
# 249              0          0     NoP    NoF         NoMF         0        3
# 256              0          0     NoP    NoF         NoMF         0        4
# 390              0          0     NoP    NoF         NoMF         0        4
# 437              0          0     NoP    NoF         NoMF         0        6
# 485              0          0     NoP    NoF         NoMF         0        4
# 499              0          0     NoP    NoF         NoMF         0        6
# 514              0          0     NoP    NoF         NoMF         0        8
# 580              0          0     NoP    NoF         NoMF         0        7
# 581              0          0     NoP    NoF         NoMF         0        3
# 616              0          0     NoP    NoF         NoMF         0        7
# 635              0          0     NoP    NoF         NoMF         0        5
# 642              0          0     NoP    NoF         NoMF         0        8
# 696              0          0     NoP    NoF         NoMF         0        4
# 700              0          0     NoP    NoF         Othr      3500        7
# 737            110          0     NoP    NoF         NoMF         0       10
# 772              0          0     NoP    NoF         NoMF         0        6
# 790            200          0     NoP   GdWo         NoMF         0        3
# 794              0          0     NoP  GdPrv         NoMF         0        8
# 924              0          0     NoP    NoF         NoMF         0        6
# 933              0          0     NoP    NoF         NoMF         0        7
# 954              0          0     NoP    NoF         NoMF         0        6
# 1007             0          0     NoP    NoF         NoMF         0        4
# 1022             0          0     NoP    NoF         NoMF         0        6
# 1049             0          0     NoP    NoF         NoMF         0        2
# 1089             0          0     NoP    NoF         NoMF         0       10
# 1098             0          0     NoP    NoF         NoMF         0        8
# 1125             0          0     NoP    NoF         NoMF         0        5
# 1147             0          0     NoP    NoF         NoMF         0       10
# 1157             0          0     NoP    NoF         NoMF         0        4
# 1211             0          0     NoP    NoF         NoMF         0       11
# 1222             0          0     NoP    NoF         NoMF         0       12
# 1252             0          0     NoP    NoF         NoMF         0        4
# 1256             0          0     NoP    NoF         NoMF         0        6
# 1270             0          0     NoP    NoF         NoMF         0       11
# 1327             0          0     NoP  MnPrv         NoMF         0        4
# 1331             0          0     NoP  MnPrv         NoMF         0        8
# 1377             0          0     NoP    NoF         Shed       500       10
# 1387             0          0     NoP    NoF         NoMF         0        6
# 1428             0          0     NoP    NoF         NoMF         0        1
# 1481             0          0     NoP    NoF         Shed       600        6
# 1594             0          0     NoP    NoF         NoMF         0        6
# 1620             0          0     NoP    NoF         NoMF         0        6
# 1681             0          0     NoP    NoF         NoMF         0        3
# 1684             0          0     NoP    NoF         NoMF         0        5
# 1686             0          0     NoP    NoF         NoMF         0        7
# 1859             0          0     NoP    NoF         NoMF         0       12
# 1875             0        561      TA  GdPrv         NoMF         0        6
# 1889             0          0     NoP    NoF         NoMF         0        6
# 1933             0          0     NoP    NoF         NoMF         0        5
# 2010             0          0     NoP    NoF         NoMF         0       10
#
#       yr_sold sale_type  saleprice
# 12       2009       WD      131000
# 93       2009       WD      118858
# 114      2009       WD       63900
# 146      2009     ConLD     198500
# 183      2008       WD       13100
# 240      2006       WD      135000
# 249      2007       WD       68104
# 256      2006       WD       93000
# 390      2010       WD      112000
# 437      2008       WD       82000
# 485      2010       WD      107500
# 499      2009       WD      118858
# 514      2007       WD       80000
# 580      2008       WD       82500
# 581      2009     ConLD      57625
# 616      2008       WD      284700
# 635      2006       WD       81500
# 642      2009       COD     126000
# 696      2010     ConLD      84900
# 700      2010       WD       55000
# 737      2009       WD      122000
# 772      2009       WD       90000
# 790      2008       WD       98000
# 794      2008       WD       89900
# 924      2009       WD       92900
# 933      2008       WD      134432
# 954      2006       WD      109500
# 1007     2007       WD      103000
# 1022     2006       WD      125000
# 1049     2007       WD      141000
# 1089     2009       WD       45000
# 1098     2008       WD      106250
# 1125     2006       WD       87500
# 1147     2009       WD      284000
# 1157     2009       WD       98000
# 1211     2006       WD      230000
# 1222     2008       WD       97000
# 1252     2010       WD       84900
# 1256     2009       WD      142953
# 1270     2008       WD      100000
# 1327     2008     ConLD      79000
# 1331     2009     ConLD     102900
# 1377     2006       WD       90000
# 1387     2009       WD      139600
# 1428     2007       WD       39300
# 1481     2006       WD      131000
# 1594     2008       WD       82000
# 1620     2009       WD      113722
# 1681     2007       WD      101800
# 1684     2007       WD      104500
# 1686     2006       WD       93500
# 1859     2006       WD       81400
# 1875     2007       WD      130000
# 1889     2009       WD      147983
# 1933     2006       WD      169000
# 2010     2006       WD       51689

# %%
# replaced the row with null values for bsmt type 2 with Unf becasue this property has basement unfinished

df.loc[1147,'bsmtfin_type_2'] = 'Unf'

# %%
# get value count of bsmt fin type 2

df['bsmtfin_type_2'].value_counts()
# Out:
# Unf    1750
# Rec      80
# LwQ      60
# BLQ      48
# ALQ      35
# GLQ      23
# Name: bsmtfin_type_2, dtype: int64

# %%
# replace null values with NoB to represent no basement

df['bsmtfin_type_2'] = df['bsmtfin_type_2'].fillna('NoB')

# %%
# replace null values with none because properties do not have garages

df['garage_yr_blt'] = df['garage_yr_blt'].fillna('None')

# %%
null_columns = df.columns[df.isnull().any()]
df[null_columns].isnull().sum()
# Out:
# mas_vnr_type    22
# dtype: int64

# %% [markdown]
# # Covert nominal category to intergers
#
# df = pd.get_dummies(data = df, columns=['ms_zoning', 'street', 'alley',
#                                    'land_contour', 'lot_config',
#                                    'neighborhood', 'condition_1',
#                                    'condition_2', 'bldg_type', 'house_style',
#                                    'roof_style', 'roof_matl', 'exterior_1st',
#                                    'exterior_2nd', 'mas_vnr_type', 'foundation',
#                                    'heating', 'central_air', 'garage_type', 'misc_feature'], drop_first = True).head()

# %% [markdown]
# ### Modeling

# %% [markdown]
# ### Baseline Model

# %% [markdown]
# ### Linear Regression

# %% [markdown]
# ### Instantiate

# %% [markdown]
# ### Model Selection

# %% [markdown]
# ### Model Evaluation

# %% [markdown]
# ### Conclusion

# %% [markdown]
# ### Recommendations

# %% [markdown]
# ### References
